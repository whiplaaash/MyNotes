# %% [markdown]
# # Lesson 19b: Pandas - Data Frame - cont-1

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math as math

# %% [markdown]
# ## Load the data

# %%
frame = pd.read_csv("Mcdonalds.csv", usecols = ["Item", "Category", "Serving Size", "Calories", "TotalFat"])
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %% [markdown]
# ## Sorting and comparing data

# %%
frame.sort_values(by = "Calories", ascending = False).head()
# Out:
#           Category                                               Item  \
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
#
#        Serving Size  Calories  TotalFat
# 82  22.8 oz (646 g)      1880     118.0
# 32  15.3 oz (434 g)      1150      60.0
# 31  14.8 oz (420 g)      1090      56.0
# 34  15.4 oz (437 g)      1050      50.0
# 33  14.9 oz (423 g)       990      46.0

# %%
# To convert int type to float type we use:

frame["Calories"] = frame["Calories"].astype("float")

# Now we spoil one value:

frame.loc[2, "Calories"] = np.NaN

frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)     250.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       NaN
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
# What to do if we have NaN among values:
# Note that NaN is treated as the biggest number

frame.sort_values(by = "Calories").tail()
# Out:
#           Category                                               Item  \
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
# 2        Breakfast                                   Sausage McMuffin
#
#        Serving Size  Calories  TotalFat
# 34  15.4 oz (437 g)    1050.0      50.0
# 31  14.8 oz (420 g)    1090.0      56.0
# 32  15.3 oz (434 g)    1150.0      60.0
# 82  22.8 oz (646 g)    1880.0     118.0
# 2    3.9 oz (111 g)       NaN      23.0

# %%
# To show NaN at the beginning we use

frame.sort_values(by = "Calories", na_position = "first").head()
# Out:
#          Category               Item    Serving Size  Calories  TotalFat
# 2       Breakfast   Sausage McMuffin  3.9 oz (111 g)       NaN      23.0
# 114     Beverages  Diet Coke (Small)    16 fl oz cup       0.0       0.0
# 139  Coffee & Tea   Iced Tea (Large)    30 fl oz cup       0.0       0.0
# 138  Coffee & Tea  Iced Tea (Medium)    21 fl oz cup       0.0       0.0
# 137  Coffee & Tea   Iced Tea (Small)    16 fl oz cup       0.0       0.0

# %%
# To sort more than one column, and to make first column in ascending order and the second one 
# in descending order, we use

frame.sort_values(by = ["Category", "Item"], ascending = [True, False]).head(20)
# Out:
#         Category                                       Item    Serving Size  \
# 43   Beef & Pork                Quarter Pounder with Cheese  7.1 oz (202 g)
# 45   Beef & Pork  Quarter Pounder with Bacon Habanero Ranch  8.3 oz (235 g)
# 44   Beef & Pork        Quarter Pounder with Bacon & Cheese    8 oz (227 g)
# 46   Beef & Pork                     Quarter Pounder Deluxe  8.6 oz (244 g)
# 56   Beef & Pork                                      McRib  7.3 oz (208 g)
# 52   Beef & Pork                                   McDouble  5.2 oz (147 g)
# 55   Beef & Pork                            Jalapeño Double  5.6 oz (159 g)
# 48   Beef & Pork                                  Hamburger   3.5 oz (98 g)
# 47   Beef & Pork         Double Quarter Pounder with Cheese   10 oz (283 g)
# 50   Beef & Pork                        Double Cheeseburger  5.7 oz (161 g)
# 54   Beef & Pork                               Daily Double  6.7 oz (190 g)
# 49   Beef & Pork                               Cheeseburger    4 oz (113 g)
# 42   Beef & Pork                                    Big Mac  7.4 oz (211 g)
# 53   Beef & Pork                             Bacon McDouble  5.7 oz (161 g)
# 51   Beef & Pork                     Bacon Clubhouse Burger  9.5 oz (270 g)
# 126    Beverages                             Sprite (Small)    16 fl oz cup
# 127    Beverages                            Sprite (Medium)    21 fl oz cup
# 128    Beverages                             Sprite (Large)    30 fl oz cup
# 129    Beverages                             Sprite (Child)    12 fl oz cup
# 133    Beverages           Minute Maid Orange Juice (Small)    12 fl oz cup
#
#      Calories  TotalFat
# 43      520.0      26.0
# 45      610.0      31.0
# 44      600.0      29.0
# 46      540.0      27.0
# 56      500.0      26.0
# 52      380.0      17.0
# 55      430.0      23.0
# 48      240.0       8.0
# 47      750.0      43.0
# 50      430.0      21.0
# 54      430.0      22.0
# 49      290.0      11.0
# 42      530.0      27.0
# 53      440.0      22.0
# 51      720.0      40.0
# 126     140.0       0.0
# 127     200.0       0.0
# 128     280.0       0.0
# 129     100.0       0.0
# 133     150.0       0.0

# %%
# Now we will try to sort by index.

frame = pd.read_csv("Mcdonalds.csv", usecols = ["Item", "Category", "Serving Size", "Calories", "TotalFat"], 
                    index_col = "Item")
frame.head()
# Out:
#                                    Category    Serving Size  Calories  \
# Item
# Egg McMuffin                      Breakfast  4.8 oz (136 g)       300
# Egg White Delight                 Breakfast  4.8 oz (135 g)       250
# Sausage McMuffin                  Breakfast  3.9 oz (111 g)       370
# Sausage McMuffin with Egg         Breakfast  5.7 oz (161 g)       450
# Sausage McMuffin with Egg Whites  Breakfast  5.7 oz (161 g)       400
#
#                                   TotalFat
# Item
# Egg McMuffin                          13.0
# Egg White Delight                      8.0
# Sausage McMuffin                      23.0
# Sausage McMuffin with Egg             28.0
# Sausage McMuffin with Egg Whites      23.0

# %%
frame.sort_index(ascending = True).head()
# Out:
#                                      Category       Serving Size  Calories  \
# Item
# 1% Low Fat Milk Jug                 Beverages  1 carton (236 ml)       100
# Apple Slices                   Snacks & Sides      1.2 oz (34 g)        15
# Bacon Buffalo Ranch McChicken  Chicken & Fish     5.7 oz (161 g)       430
# Bacon Cheddar McChicken        Chicken & Fish       6 oz (171 g)       480
# Bacon Clubhouse Burger            Beef & Pork     9.5 oz (270 g)       720
#
#                                TotalFat
# Item
# 1% Low Fat Milk Jug                 2.5
# Apple Slices                        0.0
# Bacon Buffalo Ranch McChicken      21.0
# Bacon Cheddar McChicken            24.0
# Bacon Clubhouse Burger             40.0

# %% [markdown]
# ## Control over types

# %%
frame.dtypes
# Out:
# Category         object
# Serving Size     object
# Calories          int64
# TotalFat        float64
# dtype: object

# %%
# Memory usage control:

frame.info(memory_usage = "deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, Egg McMuffin to McFlurry with Reese's Peanut Butter Cups (Snack)
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    object
#  1   Serving Size  260 non-null    object
#  2   Calories      260 non-null    int64
#  3   TotalFat      260 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 61.5 KB

# %%
frame.loc[1, "Calories"] = np.NaN

frame.info(memory_usage = "deep")

# Note that if an int type value is changed to NaN, then the whole column type becomes float:
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261 entries, Egg McMuffin to 1
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    object
#  1   Serving Size  260 non-null    object
#  2   Calories      260 non-null    float64
#  3   TotalFat      260 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 69.8 KB

# %%
# Now it is not possible to change the type of this column by using the method "astype()".
# We have to replace NaN by some number.

frame["Calories"].fillna(value = 0, inplace = True)
frame.head()
# Out:
#                                    Category    Serving Size  Calories  \
# Item
# Egg McMuffin                      Breakfast  4.8 oz (136 g)     300.0
# Egg White Delight                 Breakfast  4.8 oz (135 g)     250.0
# Sausage McMuffin                  Breakfast  3.9 oz (111 g)     370.0
# Sausage McMuffin with Egg         Breakfast  5.7 oz (161 g)     450.0
# Sausage McMuffin with Egg Whites  Breakfast  5.7 oz (161 g)     400.0
#
#                                   TotalFat
# Item
# Egg McMuffin                          13.0
# Egg White Delight                      8.0
# Sausage McMuffin                      23.0
# Sausage McMuffin with Egg             28.0
# Sausage McMuffin with Egg Whites      23.0

# %%
# Now we can change the type of this column:

frame["Calories"] = frame["Calories"].astype(int)
frame
# Out:
#                                                              Category  \
# Item
# Egg McMuffin                                                Breakfast
# Egg White Delight                                           Breakfast
# Sausage McMuffin                                            Breakfast
# Sausage McMuffin with Egg                                   Breakfast
# Sausage McMuffin with Egg Whites                            Breakfast
# ...                                                               ...
# McFlurry with Oreo Cookies (Medium)                Smoothies & Shakes
# McFlurry with Oreo Cookies (Snack)                 Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Medium)  Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Snack)   Smoothies & Shakes
# 1                                                                 NaN
#
#                                                       Serving Size  Calories  \
# Item
# Egg McMuffin                                        4.8 oz (136 g)       300
# Egg White Delight                                   4.8 oz (135 g)       250
# Sausage McMuffin                                    3.9 oz (111 g)       370
# Sausage McMuffin with Egg                           5.7 oz (161 g)       450
# Sausage McMuffin with Egg Whites                    5.7 oz (161 g)       400
# ...                                                            ...       ...
# McFlurry with Oreo Cookies (Medium)                13.4 oz (381 g)       690
# McFlurry with Oreo Cookies (Snack)                  6.7 oz (190 g)       340
# McFlurry with Reese's Peanut Butter Cups (Medium)  14.2 oz (403 g)       810
# McFlurry with Reese's Peanut Butter Cups (Snack)    7.1 oz (202 g)       410
# 1                                                              NaN         0
#
#                                                    TotalFat
# Item
# Egg McMuffin                                           13.0
# Egg White Delight                                       8.0
# Sausage McMuffin                                       23.0
# Sausage McMuffin with Egg                              28.0
# Sausage McMuffin with Egg Whites                       23.0
# ...                                                     ...
# McFlurry with Oreo Cookies (Medium)                    23.0
# McFlurry with Oreo Cookies (Snack)                     11.0
# McFlurry with Reese's Peanut Butter Cups (Medium)      32.0
# McFlurry with Reese's Peanut Butter Cups (Snack)       16.0
# 1                                                       NaN
#
# [261 rows x 4 columns]

# %% [markdown]
# ### Reducing memory for repeated values within a column

# %%
frame["Category"].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
# Note that I can use a parameter "category" of the method "astype()"

frame["Category"] = frame["Category"].astype("category")

frame.head()

frame.info(memory_usage = "deep")

# Look at the memory saved.

# We can obviously repreat this method to other columns, if possible, and save more memory.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261 entries, Egg McMuffin to 1
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    category
#  1   Serving Size  260 non-null    object
#  2   Calories      261 non-null    int64
#  3   TotalFat      260 non-null    float64
# dtypes: category(1), float64(1), int64(1), object(1)
# memory usage: 53.4 KB

# %% [markdown]
# ## Ranking

# %%
# Ranking means ascribing positions to values:

frame.head()
# Out:
#                                    Category    Serving Size  Calories  \
# Item
# Egg McMuffin                      Breakfast  4.8 oz (136 g)       300
# Egg White Delight                 Breakfast  4.8 oz (135 g)       250
# Sausage McMuffin                  Breakfast  3.9 oz (111 g)       370
# Sausage McMuffin with Egg         Breakfast  5.7 oz (161 g)       450
# Sausage McMuffin with Egg Whites  Breakfast  5.7 oz (161 g)       400
#
#                                   TotalFat
# Item
# Egg McMuffin                          13.0
# Egg White Delight                      8.0
# Sausage McMuffin                      23.0
# Sausage McMuffin with Egg             28.0
# Sausage McMuffin with Egg Whites      23.0

# %%
frame["Calories"].rank().head()
# Out:
# Item
# Egg McMuffin                        116.0
# Egg White Delight                    83.5
# Sausage McMuffin                    147.0
# Sausage McMuffin with Egg           179.5
# Sausage McMuffin with Egg Whites    157.0
# Name: Calories, dtype: float64

# %%
frame["CaloriesRank"] = frame["Calories"].rank()

# %%
frame
# Out:
#                                                              Category  \
# Item
# Egg McMuffin                                                Breakfast
# Egg White Delight                                           Breakfast
# Sausage McMuffin                                            Breakfast
# Sausage McMuffin with Egg                                   Breakfast
# Sausage McMuffin with Egg Whites                            Breakfast
# ...                                                               ...
# McFlurry with Oreo Cookies (Medium)                Smoothies & Shakes
# McFlurry with Oreo Cookies (Snack)                 Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Medium)  Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Snack)   Smoothies & Shakes
# 1                                                                 NaN
#
#                                                       Serving Size  Calories  \
# Item
# Egg McMuffin                                        4.8 oz (136 g)       300
# Egg White Delight                                   4.8 oz (135 g)       250
# Sausage McMuffin                                    3.9 oz (111 g)       370
# Sausage McMuffin with Egg                           5.7 oz (161 g)       450
# Sausage McMuffin with Egg Whites                    5.7 oz (161 g)       400
# ...                                                            ...       ...
# McFlurry with Oreo Cookies (Medium)                13.4 oz (381 g)       690
# McFlurry with Oreo Cookies (Snack)                  6.7 oz (190 g)       340
# McFlurry with Reese's Peanut Butter Cups (Medium)  14.2 oz (403 g)       810
# McFlurry with Reese's Peanut Butter Cups (Snack)    7.1 oz (202 g)       410
# 1                                                              NaN         0
#
#                                                    TotalFat  CaloriesRank
# Item
# Egg McMuffin                                           13.0         116.0
# Egg White Delight                                       8.0          83.5
# Sausage McMuffin                                       23.0         147.0
# Sausage McMuffin with Egg                              28.0         179.5
# Sausage McMuffin with Egg Whites                       23.0         157.0
# ...                                                     ...           ...
# McFlurry with Oreo Cookies (Medium)                    23.0         241.0
# McFlurry with Oreo Cookies (Snack)                     11.0         133.5
# McFlurry with Reese's Peanut Butter Cups (Medium)      32.0         250.0
# McFlurry with Reese's Peanut Butter Cups (Snack)       16.0         160.5
# 1                                                       NaN           9.0
#
# [261 rows x 5 columns]

# %%
frame.sort_values(by = "Calories").head()

# This does not look nice.
# Out:
#                           Category  Serving Size  Calories  TotalFat  \
# Item
# 1                              NaN           NaN         0       NaN
# Diet Dr Pepper (Medium)  Beverages  21 fl oz cup         0       0.0
# Diet Dr Pepper (Large)   Beverages  30 fl oz cup         0       0.0
# Diet Dr Pepper (Child)   Beverages  12 fl oz cup         0       0.0
# Diet Coke (Large)        Beverages  30 fl oz cup         0       0.0
#
#                          CaloriesRank
# Item
# 1                                 9.0
# Diet Dr Pepper (Medium)           9.0
# Diet Dr Pepper (Large)            9.0
# Diet Dr Pepper (Child)            9.0
# Diet Coke (Large)                 9.0

# %%
# Try again

frame["CaloriesRank"] = frame["Calories"].rank(ascending = False)
frame.sort_values(by = "Calories", ascending = False).head()
# Out:
#                                                           Category  \
# Item
# Chicken McNuggets (40 piece)                        Chicken & Fish
# Big Breakfast with Hotcakes (Large Biscuit)              Breakfast
# Big Breakfast with Hotcakes (Regular Biscuit)            Breakfast
# Big Breakfast with Hotcakes and Egg Whites (Lar...       Breakfast
# Big Breakfast with Hotcakes and Egg Whites (Reg...       Breakfast
#
#                                                        Serving Size  Calories  \
# Item
# Chicken McNuggets (40 piece)                        22.8 oz (646 g)      1880
# Big Breakfast with Hotcakes (Large Biscuit)         15.3 oz (434 g)      1150
# Big Breakfast with Hotcakes (Regular Biscuit)       14.8 oz (420 g)      1090
# Big Breakfast with Hotcakes and Egg Whites (Lar...  15.4 oz (437 g)      1050
# Big Breakfast with Hotcakes and Egg Whites (Reg...  14.9 oz (423 g)       990
#
#                                                     TotalFat  CaloriesRank
# Item
# Chicken McNuggets (40 piece)                           118.0           1.0
# Big Breakfast with Hotcakes (Large Biscuit)             60.0           2.0
# Big Breakfast with Hotcakes (Regular Biscuit)           56.0           3.0
# Big Breakfast with Hotcakes and Egg Whites (Lar...      50.0           4.0
# Big Breakfast with Hotcakes and Egg Whites (Reg...      46.0           5.0

# %%
# Extract 3 the biggest values:

frame.sort_values(by = ["Calories", "Item"], ascending = [False,True], inplace = True)
frame.head(3)
# Out:
#                                                      Category  \
# Item
# Chicken McNuggets (40 piece)                   Chicken & Fish
# Big Breakfast with Hotcakes (Large Biscuit)         Breakfast
# Big Breakfast with Hotcakes (Regular Biscuit)       Breakfast
#
#                                                   Serving Size  Calories  \
# Item
# Chicken McNuggets (40 piece)                   22.8 oz (646 g)      1880
# Big Breakfast with Hotcakes (Large Biscuit)    15.3 oz (434 g)      1150
# Big Breakfast with Hotcakes (Regular Biscuit)  14.8 oz (420 g)      1090
#
#                                                TotalFat  CaloriesRank
# Item
# Chicken McNuggets (40 piece)                      118.0           1.0
# Big Breakfast with Hotcakes (Large Biscuit)        60.0           2.0
# Big Breakfast with Hotcakes (Regular Biscuit)      56.0           3.0

# %%
# Note that there is a special function to do this:

frame.nlargest(n = 3, columns = "Calories")
# Out:
#                                                      Category  \
# Item
# Chicken McNuggets (40 piece)                   Chicken & Fish
# Big Breakfast with Hotcakes (Large Biscuit)         Breakfast
# Big Breakfast with Hotcakes (Regular Biscuit)       Breakfast
#
#                                                   Serving Size  Calories  \
# Item
# Chicken McNuggets (40 piece)                   22.8 oz (646 g)      1880
# Big Breakfast with Hotcakes (Large Biscuit)    15.3 oz (434 g)      1150
# Big Breakfast with Hotcakes (Regular Biscuit)  14.8 oz (420 g)      1090
#
#                                                TotalFat  CaloriesRank
# Item
# Chicken McNuggets (40 piece)                      118.0           1.0
# Big Breakfast with Hotcakes (Large Biscuit)        60.0           2.0
# Big Breakfast with Hotcakes (Regular Biscuit)      56.0           3.0

# %%
frame.tail(5)
# Out:
#                             Category  Serving Size  Calories  TotalFat  \
# Item
# Diet Dr Pepper (Small)     Beverages  16 fl oz cup         0       0.0
# Iced Tea (Child)        Coffee & Tea  12 fl oz cup         0       0.0
# Iced Tea (Large)        Coffee & Tea  30 fl oz cup         0       0.0
# Iced Tea (Medium)       Coffee & Tea  21 fl oz cup         0       0.0
# Iced Tea (Small)        Coffee & Tea  16 fl oz cup         0       0.0
#
#                         CaloriesRank
# Item
# Diet Dr Pepper (Small)         253.0
# Iced Tea (Child)               253.0
# Iced Tea (Large)               253.0
# Iced Tea (Medium)              253.0
# Iced Tea (Small)               253.0

# %%
frame.nsmallest(n = 5, columns = "Calories")
# Out:
#                          Category  Serving Size  Calories  TotalFat  \
# Item
# 1                             NaN           NaN         0       NaN
# Coffee (Large)       Coffee & Tea  16 fl oz cup         0       0.0
# Coffee (Medium)      Coffee & Tea  16 fl oz cup         0       0.0
# Coffee (Small)       Coffee & Tea  12 fl oz cup         0       0.0
# Dasani Water Bottle     Beverages    16.9 fl oz         0       0.0
#
#                      CaloriesRank
# Item
# 1                           253.0
# Coffee (Large)              253.0
# Coffee (Medium)             253.0
# Coffee (Small)              253.0
# Dasani Water Bottle         253.0

# %%
# Note that if the values are not unique, the two methods above give different results, 
# although they all belong to the same group of "CaloriesRank".
